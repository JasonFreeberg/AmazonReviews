# %% [markdown]
# Exploratory Analysis of Amazon Product Review Data

# %%
# Modules

from helpers import *
import string, re
import pymongo as mongo
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from itertools import groupby

# %%
# Constants
DATABASE_NAME = "amazon"
COLLECTION_NAME = "electronics"
N_REVIEWS = 1000
N_COMMON_WORDS = 75

# Point to the MongoDB collection
client = mongo.MongoClient(host="localhost", port=27017)
collection = client[DATABASE_NAME][COLLECTION_NAME]

# %%
mongoPull = collection.find({}, {"overall": 1,
                                 "reviewerID": 1,
                                 "unixReviewTime": 1,
                                 "reviewText": 1,
                                 "_id": 0}).limit(N_REVIEWS)
reviews = list(mongoPull)

# %%
# Get set of common words
reviewText = [elem["reviewText"] for elem in reviews]
vectorizer = TfidfVectorizer(stop_words="english")
tfidf = vectorizer.fit_transform(reviewText)
print(tfidf)
#print(vectorizer.inverse_transform(tfidf))


#word_set = get_word_set(reviews, "reviewText", regex)
#most_common = word_set.most_common(N_COMMON_WORDS)
#common_words = [Tuple[0] for Tuple in most_common]
#common_counts = [Tuple[1] for Tuple in most_common]
#N = np.arange(N_COMMON_WORDS)
# Out:
#   (0, 3018)	0.0724974859602
#   (0, 3022)	0.114688454134
#   (0, 3376)	0.117258052174
#   (0, 4726)	0.157331794778
#   (0, 5769)	0.127315018463
#   (0, 7004)	0.314663589557
#   (0, 3445)	0.231875091815
#   (0, 6065)	0.105730073743
#   (0, 6859)	0.0626139198112
#   (0, 692)	0.104136161088
#   (0, 1824)	0.0862734874382
#   (0, 2210)	0.127315018463
#   (0, 2480)	0.103378631905
#   (0, 7410)	0.0914286769911
#   (0, 7198)	0.107265516131
#   (0, 6395)	0.112376269009
#   (0, 2841)	0.301371199024
#   (0, 3734)	0.103767240782
#   (0, 2977)	0.150685599512
#   (0, 7113)	0.175481620702
#   (0, 7525)	0.162952968885
#   (0, 3049)	0.102345431974
#   (0, 7522)	0.0661964795943
#   (0, 4559)	0.120149642467
#   (0, 4931)	0.102645155375
#   :	:
#   (998, 1304)	0.167831187903
#   (998, 2598)	0.164698642938
#   (998, 2276)	0.664278177053
#   (999, 7525)	0.159070649062
#   (999, 1035)	0.112429462491
#   (999, 4951)	0.175158227268
#   (999, 7035)	0.23022761262
#   (999, 3947)	0.21828837011
#   (999, 5187)	0.114270710497
#   (999, 3195)	0.178500816418
#   (999, 3001)	0.109144185055
#   (999, 5231)	0.137871458396
#   (999, 1948)	0.130120270669
#   (999, 7359)	0.132873252564
#   (999, 263)	0.231663239944
#   (999, 884)	0.223912052217
#   (999, 3313)	0.237686081633
#   (999, 3461)	0.182111087734
#   (999, 1311)	0.257614644255
#   (999, 3603)	0.196357417934
#   (999, 4488)	0.201831315978
#   (999, 6471)	0.29419109431
#   (999, 231)	0.307166796465
#   (999, 4373)	0.307166796465
#   (999, 4959)	0.325455021492

# %%
# %matplotlib inline

fig, axis = plt.subplots(figsize = (16.5,4))
hist_font = {"fontsize": 10}

axis.bar(N, common_counts)
axis.set_xticks(N)
axis.set_xlim(0,N_COMMON_WORDS)
axis.set_xticklabels(common_words, rotation=-45, ha="left", fontdict=hist_font)
axis.set_title("Histogram of {0} Most Common Words".format(N_COMMON_WORDS))
plt.show()

# %%
# %matplotlib inline
ratings = [int(elem["overall"]) for elem in reviews]
rating_freq = [len(list(group)) for key, group in groupby(sorted(ratings, reverse = True))]

fig, axis = plt.subplots(figsize = (16.5,4))
axis.bar(left = [1,2,3,4,5], height = rating_freq, align="center")
axis.set_xticklabels(labels=["",5,4,3,2,1])
axis.set_title("Distribution of Ratings")
plt.show()
